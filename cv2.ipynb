# %%
# import the necessary packages
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# read the image
img = cv2.imread(r"/content/Screenshot20220304172134-660x558.jpg", 0)

# %%
# binarize the image
binr = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

# define the kernel
kernel = np.ones((5, 5), np.uint8)

# invert the image
invert = cv2.bitwise_not(binr)
plt.imshow(invert, cmap='gray')

# %%
# erode the image
erosion = cv2.erode(invert, kernel,
					iterations=1)

# print the output
plt.imshow(erosion, cmap='gray')

# %%
import cv2

# read the image
img = cv2.imread(r"/content/Screenshot20220304172134-660x558.jpg", 0)

# binarize the image
binr = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

# define the kernel
kernel = np.ones((3, 3), np.uint8)

# invert the image
invert = cv2.bitwise_not(binr)

# dilate the image
dilation = cv2.dilate(invert, kernel, iterations=1)

# print the output
plt.imshow(dilation, cmap='gray')

# %%
# import the necessary packages
import cv2

# read the image
img = cv2.imread(r"/content/noise.png", 0)

# binarize the image
binr = cv2.threshold(img, 0, 255,
					cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

# define the kernel
kernel = np.ones((3, 3), np.uint8)

# opening the image
opening = cv2.morphologyEx(binr, cv2.MORPH_OPEN,
						kernel, iterations=1)
# print the output
plt.imshow(opening, cmap='gray')

# %%
# import the necessary packages
import cv2

# read the image
img = cv2.imread(r"/content/noise.png", 0)

# binarize the image
binr = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1]

# define the kernel
kernel = np.ones((3, 3), np.uint8)

# opening the image
closing = cv2.morphologyEx(binr, cv2.MORPH_CLOSE, kernel, iterations=1)

# print the output
plt.imshow(closing, cmap='gray')

# %%
# import the necessary packages
import cv2
import numpy as np
import matplotlib.pyplot as plt

# read the image
img1 = cv2.imread(r"/content/morph_close1.png", 0)

# binarize the image
binr = cv2.threshold(img1, 0, 255, cv2.THRESH_BINARY)[1]

# define the kernel
kernel = np.ones((1, 1), np.uint8)

# invert the image
invert = cv2.bitwise_not(binr)

# erode the image
erosion = cv2.erode(invert, kernel,
					iterations=1)

# print the output
plt.imshow(erosion, cmap='gray')

# %%
kernel = np.ones((18,18), np.uint8)
_,mask=cv2.threshold(img1,0,255,cv2.THRESH_BINARY)
# Using cv2.erode() method
image_erode1 = cv2.erode(mask, kernel,iterations=1)
plt.imshow(image_erode1,cmap='gray')

# %%
# Import the necessary packages
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read the image (Fig 2)
img = cv2.imread(r"/content/IMG-20240131-WA0004.jpg", 0)

# Binarize the image
binr = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# Define the kernel
kernel = np.ones((3, 3), np.uint8)

# Closing operation to fill gaps
closing = cv2.morphologyEx(binr, cv2.MORPH_CLOSE, kernel, iterations=2)

# Opening operation to remove noise
opening = cv2.morphologyEx(closing, cv2.MORPH_OPEN, kernel, iterations=2)

# Display the original, closed, and opened images side by side
plt.subplot(1, 3, 1)
plt.imshow(binr, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(closing, cmap='gray')
plt.title('After Closing')

plt.subplot(1, 3, 3)
plt.imshow(opening, cmap='gray')
plt.title('After Opening')

# Adjust layout for better display
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Read the image (Fig 3)
img2 = cv2.imread(r"/content/image_5.png", cv2.IMREAD_GRAYSCALE)

# Define the kernel for dilation and erosion
kernel = np.ones((3, 3), np.uint8)

# Grayscale Dilation
dilation = cv2.dilate(img2, kernel, iterations=1)

# Grayscale Erosion
erosion = cv2.erode(img2, kernel, iterations=1)

# Morphological Gradient
gradient = cv2.absdiff(dilation, erosion)

# Display the original, dilation, erosion, and gradient images

plt.imshow(img2, cmap='gray')
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
plt.imshow(dilation, cmap='gray')
plt.title('Dilation')
# Out:
# Text(0.5, 1.0, 'Dilation')

# %%
plt.imshow(erosion, cmap='gray')
plt.title('Erosion')
# Out:
# Text(0.5, 1.0, 'Erosion')

# %%
plt.imshow(gradient, cmap='gray')
plt.title('Morphological Gradient')

# Adjust layout for better display
plt.tight_layout()

# Show the plot
plt.show()
